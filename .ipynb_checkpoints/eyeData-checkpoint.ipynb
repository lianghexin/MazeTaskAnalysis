# %%
import pandas as pd
import numpy as np
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %%
with open('C:/Users/liang/Documents/Thesis/MazeTask/D/Raw/HMaze_2023_12_28__13_01_21/HMaze_2023_12_28__13_01_21.eye.txt', 
          'r') as file:
    
    csv_reader = csv.reader(file)

    # Initialize variables to store the combined rows
    combined_rows = [np.array([]) for x in range(3)]
    current_row = []

    # Iterate through the rows
    for row_num, row in enumerate(csv_reader):
        # Join the rows every n rows
        combined_rows[row_num % 3] =  np.concatenate((combined_rows[row_num % 3], np.array(row,dtype=np.intp)))

# %%
beh = pd.read_csv('C:/Users/liang/Documents/Thesis/MazeTask/D/Raw/HMaze_2023_12_28__13_01_21/HMaze_2023_12_28__13_01_21.beh.txt', sep=",")
beh = beh[beh.GoalBlockNum>0]

# %%
eyeData = pd.DataFrame(np.array(combined_rows).transpose(),columns=['Time','xpos','ypos'])

# %%
first_episodes = beh[beh.EpisodeNum==1]

# %%
first_trials = first_episodes[first_episodes.TrialNum==1]

# %%
plt.close('all')

sns.scatterplot(data=eye_fore,x='xpos',y='ypos',hue='Time')

# plt.xlim(0,800)
# plt.ylim(0,600)
plt.gca().invert_yaxis()
plt.show()

# %%
plt.close('all')
sns.kdeplot(data=eye_fore, x='xpos', y='ypos', fill=True)
plt.xlim(0,800)
plt.ylim(0,600)
plt.gca().invert_yaxis()

# %%
plt.close('all')
sns.lineplot(data=average,x='RelativeTime',y='OnGoal',label='Goal')
sns.lineplot(data=average,x='RelativeTime',y='OnStart',label='Start')
plt.ylabel('Percentage')
plt.xlabel('Time from cue onset (ms)')
plt.title('Fixation location')
# Out:
# Text(0.5, 1.0, 'Fixation location')

# %%
average = eye_fore.groupby('RelativeTime').mean().rolling(20, min_periods=1, center=True).mean()

# %%
eye_fore['OnGoal'] = ((eye_fore.xpos.values-400)**2 + (eye_fore.ypos.values-550)**2) < 65**2
eye_fore['OnStart'] = ((eye_fore.xpos.values-400)**2 + (eye_fore.ypos.values-300)**2) < 65**2

# %%
# plt.close('all')

eye_fore = pd.DataFrame()

for i, _  in enumerate(first_trials.index):
    temp = eyeData[(eyeData.Time > (first_trials.GoalPeriodStart.values[i] + np.floor(first_trials.GlobalStart.values[i]*1000))) & 
                       (eyeData.Time < (first_trials.ForePeriodEntry.values[i] + np.floor(first_trials.GlobalStart.values[i]*1000)))]
    temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
    temp['Trial'] = i
    sliding = temp.rolling(5,min_periods=1).mean().reset_index(drop=True)
    eye_fore = pd.concat([eye_fore,sliding[sliding.index%5==0]])
# eye_fore = eyeData[(eyeData.Time > (beh.DelayperiodExit.values[i] + np.floor(beh.GlobalStart.values[i]*1000))) & 
#                    (eyeData.Time < (beh.FeedbackPeriodEntry.values[i] + np.floor(beh.GlobalStart.values[i]*1000)))]
#     sns.scatterplot(data=eye_fore,x='xpos',y='ypos',hue='Time')
    
# plt.xlim(0,800)
# plt.ylim(0,600)
# plt.gca().invert_yaxis()
# plt.show()
# Out:
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['RelativeTime'] = temp['Time'].values - first_trials.GoalPeriodStart.values[i] - np.floor(first_trials.GlobalStart.values[i]*1000)
# C:\Users\liang\AppData\Local\Temp\ipykernel_24656\1666768942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Trial'] = i
